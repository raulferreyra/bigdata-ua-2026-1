# %% [markdown]
# # Módulo 1 — Introducción a Apache Spark

# %%
#VERIFICACION DE VERSION DE SPARK
print("Spark version:", spark.version)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #VERIFICACION DE VERSION DE SPARK
# ----> 2 print("Spark version:", spark.version)
#
# NameError: name 'spark' is not defined

# %%
#CREACION DE UN DATAFRAME PEQUEÑO
data = [("Juan", 25), ("María", 30), ("Pedro", 35)]
df = spark.createDataFrame(data, ["nombre", "edad"])
df.show()
# Out:
# +------+----+
# |nombre|edad|
# +------+----+
# |  Juan|  25|
# | María|  30|
# | Pedro|  35|
# +------+----+

# %%
# Transformación corta
df2 = df.filter(df.edad > 28)   # transformación
# Retorno de resultados
print("Filtrados:", df2.count())
df2.show()
# Out:
# Filtrados: 2
# +------+----+
# |nombre|edad|
# +------+----+
# | María|  30|
# | Pedro|  35|
# +------+----+

# %%
#display(dbutils.fs.ls('/databricks-datasets'))  # datasets de prueba

df_productos = spark.read.csv('/Volumes/workspace/default/resources/productos.csv',header=True, inferSchema=True)
display(df_productos)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Index</th><th>Name</th><th>Description</th><th>Brand</th><th>Category</th><th>Price</th><th>Currency</th><th>Stock</th><th>EAN</th><th>Color</th><th>Size</th><th>Availability</th><th>Internal ID</th></tr></thead><tbody><tr><td>1</td><td>Thermostat Drone Heater</td><td>Consumer approach woman us those star.</td><td>Bradford-Yu</td><td>Kitchen Appliances</td><td>74</td><td>USD</td><td>139</td><td>8619793560985</td><td>Orchid</td><td>Medium</td><td>backorder</td><td>38</td></tr><tr><td>2</td><td>Ultra Speaker Iron Grill Advanced One</td><td>Point suggest easy money operation could white.</td><td>Douglas Group</td><td>Fitness Equipment</td><td>510</td><td>USD</td><td>351</td><td>3057216124300</td><td>MediumSeaGreen</td><td>Small</td><td>backorder</td><td>27</td></tr><tr><td>3</td><td>Watch Headphones Kettle</td><td>Reach husband education.</td><td>Landry-Austin</td><td>Beauty & Personal Care</td><td>254</td><td>USD</td><td>409</td><td>9825254410556</td><td>Lavender</td><td>XXL</td><td>pre_order</td><td>2</td></tr><tr><td>4</td><td>Portable Toaster Clock Monitor Silent</td><td>Always choose school poor table main.</td><td>Odom, Norton and Foster</td><td>Makeup</td><td>69</td><td>USD</td><td>119</td><td>9490814777808</td><td>Pink</td><td>XL</td><td>in_stock</td><td>94</td></tr><tr><td>5</td><td>Pro Toaster Oven</td><td>Worry put discuss easy back too career.</td><td>Fowler, Mendoza and Mcdaniel</td><td>Automotive</td><td>525</td><td>USD</td><td>727</td><td>4726650403799</td><td